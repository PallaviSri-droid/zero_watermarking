# %% [markdown]
# # Classical benchmark
#
# Run all classical baselines under identical preprocessing, hash length and attacks.

# %%
from zero_watermarking.benchmark import run_benchmark
df=run_benchmark(n_images=40,image_size=224,hash_length=256,seed=42)
df.round(4)

# %%
from zero_watermarking.visualization import save_summary_bars, plot_pareto
save_summary_bars(df); plot_pareto(df)
df.sort_values('collision_gap',ascending=False)[['method','collision_gap','mean_nc','mean_intra_hd','mean_inter_hd','auc','eer']]
