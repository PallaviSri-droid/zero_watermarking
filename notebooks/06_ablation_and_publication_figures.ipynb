# %% [markdown]
# # Ablation and publication figures
#
# Report mean ± 95% bootstrap confidence intervals after removing one component at a time.
#
# Suggested rows: baseline, +balanced, +stability, +contrastive, +collision loss, +STE, +Pareto weighting, full model.

# %%
import pandas as pd
from pathlib import Path
p=Path('experiments/results/benchmark_summary.csv')
if p.exists():
    df=pd.read_csv(p)
    print(df.sort_values(['auc','collision_gap'],ascending=[False,False]).to_string(index=False))
else:
    print('Run notebook 02 first.')

# %% [markdown]
# ## Publication figure checklist
#
# 1. Architecture diagram.  2. Robustness-vs-attack-strength curves.  3. Intra/inter Hamming distributions.  4. ROC/EER.  5. Attack heatmap.  6. Collision-gap comparison.  7. Bit balance/entropy.  8. Correlation heatmap.  9. Ablation with confidence intervals.  10. Runtime/parameter table.
