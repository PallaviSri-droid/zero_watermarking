# %% [markdown]
# # CAP-ZW Research Map
#
# Hypothesis: explicit collision-aware optimization can improve the robustness/discriminability trade-off compared with single-objective baselines.
#
# This notebook fixes the evaluation protocol before results are reported.

# %% [markdown]
# ## Experimental ladder
#
# E0 DCT-Mean → E1 KAZE-DCT → E2 Balanced → E3 Stability → E4 Contrastive → E5 Collision-aware → E6 STE/BEMQ → E7 Pareto → E8 Full CAP-ZW → E9 Ablation.

# %%
from pathlib import Path
print(Path.cwd())
print('No fabricated results: run the benchmark to generate CSVs.')
